# %%
import numpy 
from sklearn.linear_model import LinearRegression

t = [[24], [25], [26], [27], [28], [29], [30], [31]]
p = [18, 20, 25, 29, 31, 29, 33, 76]

reg = LinearRegression()
reg = reg.fit(t, p)

t1 = [[24], [31]]
p1 = reg.predict(t1)
print(f"Predicted values for {t1} are {p1}")
# Out:
# Predicted values for [[24], [31]] are [12.41666667 52.83333333]

# %%
pp = reg.predict(t)
plt.figure(figsize=(20, 10))
plt.plot(t, pp, 'b--')
plt.scatter(t, p, s=100)
plt.show()
